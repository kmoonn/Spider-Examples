# %%
# !pip install pycryptodome
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 3.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.6 MB/s eta 0:00:00
# ...

# %%
from Crypto.Cipher import DES
import base64
import json
from pprint import pprint

def decrypt(cipher_text_base64: str, key: str) -> dict:
    # 确保 key 长度为 8 字节
    key_bytes = key.encode('utf-8')
    if len(key_bytes) != 8:
        raise ValueError("DES 密钥必须是 8 字节")

    # 解码 Base64
    cipher_bytes = base64.b64decode(cipher_text_base64)

    # 解密 (ECB 模式, PKCS7 Padding)
    cipher = DES.new(key_bytes, DES.MODE_ECB)
    decrypted = cipher.decrypt(cipher_bytes)

    # 去除 PKCS7 padding
    padding_len = decrypted[-1]
    decrypted = decrypted[:-padding_len]

    # 返回 JSON 解析结果
    return json.loads(decrypted.decode('utf-8'))

# 示例用法
if __name__ == "__main__":
    encrypted_str = "  Nf4g/CrcO/U1s0/jJiU1MeKDfUye8gIOlBSONE08/2 hnWfCvQnyzxHW2heCUj2Cz9vNaWHSHtuy5VwozUKUzLoWJRe0qxLWTOsiF26/udQHyTGcYhgaX811OG1rQrruu2HagQ1vEeI33DxtUky1lVEnyDvVYXD2Zqs755h84y1BOHZbBD7734ULy5xd2ilLEAvIFanGzB+1n/DENmzPW+aMYboTIZiKtCQWPOvrVxXW38l7Utej2XA/AXsNz2q5C1+9 ...  oXFalSdxIZiKtCQWPOvpSsA0fy0V6foGnC1UkNmo1IXyhtmjBc9emBLUTngX5X0kuBx8lre/IgS7qGuf66Y4R7a8gHEkSCkogYU5YUhMZ54eJI7QcBAQ03+yAH7Bc1NL04L+zFxlisTSimSgudjW78yrrPAb2GZ3IWPDBlV2UYZBF6z+6 f5nVPFw+nw/aE6PlqKG3fiABw3bE6p5ZQwN5kFymGYy1oPLmn0vo6YLiH/xhfYWhyHYqMcC2LnpVcb0eL5oGXKpDEC763b/+4  aVv2n7fJ4vGRwEehMGN9R9WA9N2kZf9wdlY/8 yNYTuuMQVqkcqY2WnCeV6U5YmvTm99RqUSOA6439kuvfq7Y40bFQzqFWRJWJYUoQXlFft9VM3qMJbcvY9W3Fs8m6taI6xlDPi5WL7pXl9rOTQTjD5mqKjycjLZ3oKttpwldvy03W8cssygHk4TQZhl/6 vblWW71I/D8NfuxlDmS9ho9s7cBJUvpd5Xq7x+oIlNTHig31MnYj5DcPqaCs9PP9oZ1nwr0Njmdd0pE7vqHVqnsej629zrYwh/8 CyLUK9zq91e4+T4sEq8iP2zvUj06aXhFPRoiow3JsoFih7tTOpWCeMjdBCu+WP2pGn/pzfVdj2nB9NL42QkofrdIHPZaD9cuhXzW3hUjw76LujXNqZqM45v6FvtE9K/1 RRuaDY1ib/crOv2Vq8Fk18RTnQFeq74G3XaSQQ1hWTNu1h5Xh+0 tIy1Td9PnnaNmP/2 osm0eTCXtJVGhtbOsc0Svc2L1VKolrgEmrnqav9Awo1XnFzGYwBUis6llp1akkbLzxucI4asLDYvCim+wxbd2ajq8VGsnKMslq2WXthVxj7V9VfB+CYy/d2FQRfxgbrQT7mAW+2 ... ... b6JFnFz4Ea9Cg/fkJXpyJiknRrmOull/jWDSwwe66eG7SP1babWc8nNFDfSZZeL2uGJVXpUOrIJzRQ30mWXi8zFP7LMKSbUxE4MROLsl1ceNvQ/x0GbJg2NYm/3 Kzr9q6iQzN+/sUqAHGajDShPmSogcMRJcHe8Ren84gVGYC3lEGRjd1FH3ncniDjY6tG8rQDEt/7 ..."
    key = "IFROMC86"
    
    try:
        result = decrypt(encrypted_str, key)
        data = result['data']['resultsData']
        pprint(data)
        print(len(data))
    except Exception as e:
        print("解密失败:", str(e))
# Out:
# [['585848f729f1b66508387c22a9dfeea1',
#   '线性群轨道结构与有限群的算术性质',
#   '11671063',
#   '面上项目',
#   '重庆文理学院',
#   '杨勇',
#   '48.0',
#   '2016',
#   '算术性质;群作用;特征标与共轭类;模表示;轨道结构',
#   'true',
#   '41;0;0;0;0',
#   '08df0b5302ac1f9a85d89030cede8698',
#   '229ebddee6a3629d52df4ebbfc6fa63a',
#   'true',
#   'A0104',
#   '2020',
#   '',
#   '',
#   ''],
#  ['f23fa31946f9563b9541f70ed1a76bca',
#   '若干典型空间的结构及子流形的刻画与分类研究',
#   '11671121',
#   '面上项目',
#   '河南师范大学',
#   '李兴校',
#   '50.0',
#   '2016',
#   '自然诱导的几何结构;广义自收缩子;高余维子流形;平行平均曲率向量场;刚性与分类定理',
#   'true',
#   '43;0;0;0;0',
#   '79d6387ac7529f4681904edfb5c22f24',
#   'a802d390fcf53548fffaf0cafedeeb51',
#   'true',
#   'A0108',
#   '2020',
#   '',
#   '',
#   ''],
#  ['8a4811b036a53bdb1d9bb38a646135e5',
#   '顶点算子代数的结构和表示理论',
#   '11671277',
#   '面上项目',
#   '四川大学',
#   '任丽',
#   '48.0',
#   '2016',
#   '月光顶点算子代数;模顶点算子代数;顶点算子代数;有理性;orbiford理论',
#   'true',
#   '7;0;0;0;0',
#   'befbedaeecdfafd12f6d5875502f6009',
# ...

# %%
'''
编号
项目名称
项目批准号
项目类别
依托单位
项目负责人
资助经费（万元）
批注年度
关键词
1
2
3
4
5
申请代码
结题年度
'''

# https://kd.nsfc.cn/finalDetails?id=
'''
研究期限 researchTimeScope
项目参与人 participatantsList
中文摘要 projectAbstractC
英文摘要 projectAbstractE
结题摘要 conclusionAbstract
'''

# https://kd.nsfc.cn/api/baseQuery/completeProjectReport
'''
url
index
'''
# Out:
# '\nurl\nindex\n'

# %%
payload = {"code":"A01","fuzzyKeyword":"","complete":'true',"isFuzzySearch":'false',"conclusionYear":"2020","dependUnit":"","keywords":"","pageNum":0,"pageSize":10,"personInCharge":"","projectName":"","projectType":"218","subPType":"","psPType":"","ratifyNo":"","ratifyYear":"","order":"enddate","ordering":"desc","codeScreening":"","dependUnitScreening":"","keywordsScreening":"","projectTypeNameScreening":""}
payload
# Out:
# {'code': 'A01',
#  'fuzzyKeyword': '',
#  'complete': 'true',
#  'isFuzzySearch': 'false',
#  'conclusionYear': '2020',
#  'dependUnit': '',
#  'keywords': '',
#  'pageNum': 0,
#  'pageSize': 10,
#  'personInCharge': '',
#  'projectName': '',
#  'projectType': '218',
#  'subPType': '',
#  'psPType': '',
#  'ratifyNo': '',
#  'ratifyYear': '',
#  'order': 'enddate',
#  'ordering': 'desc',
#  'codeScreening': '',
#  'dependUnitScreening': '',
#  'keywordsScreening': '',
#  'projectTypeNameScreening': ''}

# %%
# {'code': 'A01',  申请代码
#  'fuzzyKeyword': '', 
#  'complete': 'true',
#  'isFuzzySearch': 'false',
#  'conclusionYear': '2020', 结题年度
#  'dependUnit': '',
#  'keywords': '',
#  'pageNum': 0,
#  'pageSize': 10,
#  'personInCharge': '',
#  'projectName': '',
#  'projectType': '218', 资助类别
#  'subPType': '',
#  'psPType': '',
#  'ratifyNo': '',
#  'ratifyYear': '',
#  'order': 'enddate',
#  'ordering': 'desc',
#  'codeScreening': '',
#  'dependUnitScreening': '',
#  'keywordsScreening': '',
#  'projectTypeNameScreening': ''}

# %%
conclusionYears = list(range(1986,2026))
projectTypes = {
    '面上项目': '218',
    '重点项目': '220',
    '重大研究计划': '339',
    '联合基金项目': '579',
    '青年科学基金项目': '630',
    '地区科学基金项目': '631',
    '专项基金项目': '649',
    '数学天元基金项目': '80',
}

codes = [item.split()[0] for item in '''A01 代数与几何
A02 分析学
A03 微分方程与动力系统
A04 统计与运筹
A05 计算数学
A06 数学与其他学科的交叉
A07 动力学与控制
A08 固体力学
A09 流体力学
A10 生物力学
A11 物理力学
A12 爆炸与冲击动力学
A13 环境力学
A14 宇宙学和星系
A15 恒星与星际介质
A16 太阳物理
A17 行星科学
A18 基本天文学
A19 天文技术和方法
A20 凝聚态物理
A21 原子分子物理
A22 光学
A23 声学
A24 量子调控
A25 基础物理
A26 粒子物理
A27 核物理
A28 加速器、反应堆与探测器
A29 等离子体物理
A30 核技术及其应用
A31 NSFC-中物院联合基金
A32 大科学装置联合基金
A33 天文联合基金
B01 合成化学
B02 催化与表界面化学
B03 化学理论与机制
B04 化学测量学
B05 材料化学
B06 环境化学
B07 化学生物学
B08 化学工程与工业化学
B09 能源化学
C01 微生物学
C02 植物学
C03 生态学
C04 动物学
C05 生物物理与生物化学
C06 遗传学与生物信息学
C07 细胞生物学
C08 免疫学
C09 神经科学与心理学
C10 生物材料、成像与组织工程学
C11 生理学与整合生物学
C12 发育生物学与生殖生物学
C13 农学基础与作物学
C14 植物保护学
C15 园艺学与植物营养学
C16 林学与草学
C17 畜牧学
C18 兽医学
C19 水产学
C20 食品科学
C21 分子生物学与生物技术
D01 地理科学
D02 地质学
D03 地球化学
D04 地球物理学和空间物理学
D05 大气科学
D06 海洋科学
D07 环境地球科学
E01 金属材料
E02 无机非金属材料
E03 有机高分子材料
E04 矿业与冶金工程
E05 机械设计与制造
E06 工程热物理与能源利用
E07 电气科学与工程
E08 建筑与土木工程
E09 水利工程
E10 环境工程
E11 海洋工程
E12 交通与运载工程
E13 新概念材料与材料共性科学
F01 电子学与信息系统
F02 计算机科学
F03 自动化
F04 半导体科学与信息器件
F05 光学和光电子学
F06 人工智能
F07 交叉学科中的信息科学
G01 管理科学与工程
G02 工商管理
G03 经济科学
G04 宏观管理与政策
H01 呼吸系统
H02 循环系统
H03 消化系统
H04 生殖系统/围生医学/新生儿
H05 泌尿系统
H06 运动系统
H07 内分泌系统/代谢和营养支持
H08 血液系统
H09 神经系统
H10 精神卫生与心理健康
H11 医学免疫学
H12 皮肤病学
H13 眼科学
H14 耳鼻咽喉头颈科学
H15 口腔颅颌面科学
H16 急重症医学
H17 创伤/烧伤/整形
H18 肿瘤学
H19 老年医学
H20 康复医学
H21 医学病毒学与病毒感染
H22 医学病原生物与感染
H23 医学遗传学
H24 特种医学
H25 法医学
H26 检验医学
H27 影像医学/核医学
H28 生物医学工程/再生医学
H29 放射医学
H30 预防医学
H31 中医学
H32 中药学
H33 中西医结合
H34 药物学
H35 药理学'''.split("\n")]

# %%
conclusionYears
# Out:
# [1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025]

# %%
projectTypes
# Out:
# {'面上项目': '218',
#  '重点项目': '220',
#  '重大研究计划': '339',
#  '联合基金项目': '579',
#  '青年科学基金项目': '630',
#  '地区科学基金项目': '631',
#  '专项基金项目': '649',
#  '数学天元基金项目': '80'}

# %%
#!/usr/bin/env Python
# -*- coding: utf-8 -*-

import requests

def get_proxies():
    # 隧道域名:端口号
    tunnel = "y523.kdltps.com:15818"
    
    # 用户名密码方式
    username = "t14763510797655"
    password = "pvk2hkd3"
    proxies = {
        "http": "http://%(user)s:%(pwd)s@%(proxy)s/" % {"user": username, "pwd": password, "proxy": tunnel},
        "https": "http://%(user)s:%(pwd)s@%(proxy)s/" % {"user": username, "pwd": password, "proxy": tunnel}
    }
    
    # 白名单方式（需提前设置白名单）
    # proxies = {
    #     "http": "http://%(proxy)s/" % {"proxy": tunnel},
    #     "https": "http://%(proxy)s/" % {"proxy": tunnel}
    # }
    
    return proxies

# 要访问的目标网页
target_url = "https://dev.kdlapi.com/testproxy"

# 使用隧道域名发送请求
response = requests.get(target_url, proxies=get_proxies())

# 获取页面内容
if response.status_code == 200:
    print(response.text)  # 请勿使用keep-alive复用连接(会导致隧道不能切换IP)
# Out:
# sucess! client ip: 27.47.11.234

# %%
def get_list(pageNum):
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36 Edg/136.0.0.0'
    }
    
    payload = {
        'code': 'A',
         'fuzzyKeyword': '',
         'complete': 'true',
         'isFuzzySearch': 'false',
         'conclusionYear': '2020',
         'dependUnit': '',
         'keywords': '',
         'pageNum': pageNum,
         'pageSize': 10,
         'personInCharge': '',
         'projectName': '',
         'projectType': '579',
         'subPType': '',
         'psPType': '',
         'ratifyNo': '',
         'ratifyYear': '',
         'order': 'enddate',
         'ordering': 'desc',
         'codeScreening': '',
         'dependUnitScreening': '',
         'keywordsScreening': '',
         'projectTypeNameScreening': ''
    }
    target_url = "https://kd.nsfc.cn/api/baseQuery/completionQueryResultsData"
    response = requests.post(target_url, headers=headers, json=payload,proxies=get_proxies())
    if response.status_code == 200:
        content = response.text
        return content
    else:
        print(response.text)

# %%
def process(data):
    for item in data:
        item = item[:9] + item[14:]
        for key, value in zip(fields, item):
            dic[key].append(value)

# %%
import os
import pandas as pd
from openpyxl import load_workbook


if __name__ == '__main__':
    dic = {
        '编号': [],
        '项目名称': [],
        '项目批准号': [],
        '项目类别': [],
        '依托单位': [],
        '项目负责人': [],
        '资助经费（万元）': [],
        '批注年度': [],
        '关键词': [],
        '申请代码': [],
        '结题年度': []
    }
    
    fields = list(dic.keys())

    content = get_list(100)
    result = decrypt(content, key = "IFROMC86")
    data = result['data']['resultsData']
    process(data)
    df = pd.DataFrame(dic)
    
    pprint(df)
    
    file_path = "样例数据.xlsx"
    sheet_name = "Sheet1"

    
    if os.path.exists(file_path):
        book = load_workbook(file_path)

        if sheet_name in book.sheetnames:
            start_row = book[sheet_name].max_row
        else:
            start_row = 0

        with pd.ExcelWriter(
            file_path,
            engine="openpyxl",
            mode="a" if os.path.exists(file_path) else "w",
            if_sheet_exists="overlay"
        ) as writer:
            df.to_excel(writer, index=False, header=(start_row == 0), startrow=start_row)
            print("✅ 数据已成功追加写入 Excel。")

    else:
        df.to_excel(file_path, index=False)
        print("📄 文件不存在，已创建并写入 Excel。")
# Out:
#                                  编号                             项目名称  \
# 0  eda6582eb820ef8540534a504a5b41e9      微聚焦三维SAXS技术及其在聚乳酸注塑成型中的应用研究
# 1  fb973971481550d9e20cdb802a2d2a7a             弹性相变复合材料的导热网络设计及机理研究
# 2  e2ef9dcdb102ac0addcf5c1b4933d332        利用数值模型研究由太阳调制引发的正电子各向异性特征
# 3  e60359f57722b2c8e6b68d8461b5c04d            利用同步辐射发展高压下的原子对分布函数方法
# 4  a55e04074aff407e53b896b292443404      端粒蛋白质复合体在哺乳动物减数分裂前期的结构和功能研究
# 5  5457d9484a5d518be81d1e5086a041c6  基于同步辐射的铋基钙钛矿无铅铁电陶瓷压电响应及其相结构本质研究
# 6  91cc01ed469c9e0c0c3f9aa114edcac8                 空间辐射对基因组的作用及机理研究
# 7  a2271bd2938942550cf7b355182020a9           多晶金属材料动态力学行为的位错动力学塑性模型
# 8  b313e618771864dbc1e0916dbbeca3fa        压装PBX炸药结构、组成同力学性能间关系模型的建立
# 9  0ac5307acff0fe998c2f0e82d029d8d7           热-力载荷下陶瓷材料体应力及裂纹演化机制研究
#
#       项目批准号    项目类别            依托单位 项目负责人 资助经费（万元）  批注年度  \
# 0  U1732123  联合基金项目  中国科学院上海应用物理研究所   边风刚     58.0  2017
# 1  U1730114  联合基金项目          西南科技大学   杨文彬     64.0  2017
# ...
